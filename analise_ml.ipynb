# %%
# ============================
# IMPORTAÇÕES
# ============================

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, f1_score, roc_auc_score
from sklearn.impute import SimpleImputer

# Modelos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

sns.set(style="whitegrid")

print("✓ Todos os pacotes importados com sucesso!")

# Verificar versões
print(f"\nVersões instaladas:")
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"sklearn: {sklearn.__version__}")
# Out:
# ✓ Todos os pacotes importados com sucesso!
#
# Versões instaladas:
# pandas: 2.3.1
# numpy: 2.3.1
# matplotlib: 3.10.5
# seaborn: 0.13.2
# sklearn: 1.7.1

# %%
# ============================
# CARREGAR PLANILHA
# ============================

df = pd.read_excel("projetos_completos_final.xlsx")
df.head()
# Out:
#                                    guid      nome_projeto subsecretaria  \
# 0  01fb8247-91ec-4631-bf1f-3da9fa6822d6  Projeto 01fb8247          SIEC
# 1  022ea245-c8f4-440a-9a1b-2aa0e2f523fd  Projeto 022ea245          SISU
# 2  03175202-1983-4ce9-9425-f8271bf2e138  Projeto 03175202          SIEC
# 3  03476266-e9a1-4821-8179-8abd15903f7b  Projeto 03476266          SIEC
# 4  07fb13d8-0616-41f8-ab50-99c1c6669fd7  Projeto 07fb13d8          SIEC
#
#                              status_atual_do_projeto  \
# 0  Relatório final aprovado pela ANTT em 29/01/26...
# 1                               Estudos em andamento
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      questoes_chaves  \
# 0                                                NaN
# 1  Delegações do serviço embarcado\nPossibilidade...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      proximas_etapas status_dos_estudos  \
# 0                                                NaN          Completed
# 1  Conclusão dos estudos\nRealizar Consulta/Audiê...                NaN
# 2                                                NaN        In progress
# 3                                                NaN          Completed
# 4                                                NaN          Completed
#
#   status_consulta_publica status_do_tcu status_do_edital  ... custo_estimado  \
# 0               Completed           NaN              NaN  ...   2.605232e+09
# 1                     NaN           NaN              NaN  ...   1.817490e-01
# 2             Not started   Not started      Not started  ...   0.000000e+00
# 3               Completed   Not started      Not started  ...   2.552000e+09
# 4               Completed     Completed        Completed  ...   3.719562e+06
#
#   moeda custo_original status_atividade eh_ppp               tipo_projeto  \
# 0   BRL    14000000000           Active   True  Refurbishment/Replacement
# 1   BRL              1           Active   True                        New
# 2   BRL              1              NaN   True  Refurbishment/Replacement
# 3   BRL    14500000000           Active   True                        New
# 4   BRL       21133873              NaN   True  Refurbishment/Replacement
#
#                            arranjo_contratual processo_licitacao  \
# 0                    Concession: Law 8.987/95                NaN
# 1                    Concession: Law 8.987/95                NaN
# 2                    Concession: Law 8.987/95        Competition
# 3  Extension: Law 13.448/17, Art. 4, I and II        Competition
# 4                    Concession: Law 8.987/95        Competition
#
#   outro_arranjo_contratual  outro_processo_licitacao
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
# [5 rows x 32 columns]

# %%
# ============================
# SELEÇÃO DE VARIÁVEIS
# ============================

features = [
    "custo_estimado",
    "eh_ppp",
    "tipo_projeto",
    "arranjo_contratual",
    "processo_licitacao",
    "setor",
    "subsetor",
    "organizacao"
]

df_cluster = df[features].copy()

df_cluster.head()
# Out:
#    custo_estimado  eh_ppp               tipo_projeto  \
# 0    2.605232e+09    True  Refurbishment/Replacement
# 1    1.817490e-01    True                        New
# 2    0.000000e+00    True  Refurbishment/Replacement
# 3    2.552000e+09    True                        New
# 4    3.719562e+06    True  Refurbishment/Replacement
#
#                            arranjo_contratual processo_licitacao      setor  \
# 0                    Concession: Law 8.987/95                NaN  Transport
# 1                    Concession: Law 8.987/95                NaN      Other
# 2                    Concession: Law 8.987/95        Competition  Transport
# 3  Extension: Law 13.448/17, Art. 4, I and II        Competition  Transport
# 4                    Concession: Law 8.987/95        Competition  Transport
#
#          subsetor organizacao
# 0         Highway       SEPPI
# 1           Other       SEPPI
# 2         Seaport       SEPPI
# 3  Intercity Rail       SEPPI
# 4         Seaport       SEPPI

# %%
# ============================
# TRATAMENTO DE NULOS
# ============================

# Numérica
df_cluster["custo_estimado"] = df_cluster["custo_estimado"].fillna(
    df_cluster["custo_estimado"].median()
)

# Categóricas
for col in df_cluster.columns:
    if df_cluster[col].dtype == "object":
        df_cluster[col] = df_cluster[col].fillna("Desconhecido")

df_cluster.isna().sum()
# Out:
# custo_estimado        0
# eh_ppp                0
# tipo_projeto          0
# arranjo_contratual    0
# processo_licitacao    0
# setor                 0
# subsetor              0
# organizacao           0
# dtype: int64

# %%
# ============================
# PRÉ-PROCESSAMENTO
# ============================

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

numeric_features = ["custo_estimado"]
categorical_features = [
    "eh_ppp",
    "tipo_projeto",
    "arranjo_contratual",
    "processo_licitacao",
    "setor",
    "subsetor",
    "organizacao"
]

preprocess = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
    ]
)

X_processed = preprocess.fit_transform(df_cluster)

X_processed.shape
# Out:
# (209, 41)

# %%
# ============================
# MÉTODO DO COTOVELO
# ============================

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []

for k in range(2, 7):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_processed)
    inertia.append(kmeans.inertia_)

plt.plot(range(2, 7), inertia)
plt.xlabel("Número de Clusters (k)")
plt.ylabel("Inertia")
plt.title("Método do Cotovelo")
plt.show()

# %%
# ============================
# SILHOUETTE SCORE
# ============================

from sklearn.metrics import silhouette_score

for k in range(2, 7):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_processed)
    score = silhouette_score(X_processed, labels)
    print(f"k={k} → Silhouette Score: {score:.4f}")
# Out:
# k=2 → Silhouette Score: 0.5247
# k=3 → Silhouette Score: 0.2289
# k=4 → Silhouette Score: 0.2782
# k=5 → Silhouette Score: 0.3568
# k=6 → Silhouette Score: 0.3461

# %%
# ============================
# TREINAMENTO FINAL
# ============================

k_final = 3

kmeans_final = KMeans(n_clusters=k_final, random_state=42, n_init=10)
df_cluster["cluster"] = kmeans_final.fit_predict(X_processed)

df_cluster["cluster"].value_counts()
# Out:
# cluster
# 0    132
# 2     68
# 1      9
# Name: count, dtype: int64

# %%
# ============================
# ANÁLISE DOS CLUSTERS
# ============================

df_analysis = df_cluster.copy()

summary = df_analysis.groupby("cluster").agg({
    "custo_estimado": ["mean", "median", "count"],
    "eh_ppp": lambda x: (x == True).mean()
})

summary
# Out:
#         custo_estimado                       eh_ppp
#                   mean        median count <lambda>
# cluster
# 0         1.367506e+08  3.736722e+06   132      1.0
# 1         3.484000e+09  3.330800e+09     9      1.0
# 2         1.104576e+08  1.533569e+07    68      1.0

# %%
# ============================
# VISUALIZAÇÃO 2D (PCA)
# ============================

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_processed)

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=df_cluster["cluster"])
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("Visualização dos Clusters")
plt.show()

# %%
import pandas as pd

df = pd.read_excel("projetos_completos_final.xlsx")

df.head()
# Out:
#                                    guid      nome_projeto subsecretaria  \
# 0  01fb8247-91ec-4631-bf1f-3da9fa6822d6  Projeto 01fb8247          SIEC
# 1  022ea245-c8f4-440a-9a1b-2aa0e2f523fd  Projeto 022ea245          SISU
# 2  03175202-1983-4ce9-9425-f8271bf2e138  Projeto 03175202          SIEC
# 3  03476266-e9a1-4821-8179-8abd15903f7b  Projeto 03476266          SIEC
# 4  07fb13d8-0616-41f8-ab50-99c1c6669fd7  Projeto 07fb13d8          SIEC
#
#                              status_atual_do_projeto  \
# 0  Relatório final aprovado pela ANTT em 29/01/26...
# 1                               Estudos em andamento
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      questoes_chaves  \
# 0                                                NaN
# 1  Delegações do serviço embarcado\nPossibilidade...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      proximas_etapas status_dos_estudos  \
# 0                                                NaN          Completed
# 1  Conclusão dos estudos\nRealizar Consulta/Audiê...                NaN
# 2                                                NaN        In progress
# 3                                                NaN          Completed
# 4                                                NaN          Completed
#
#   status_consulta_publica status_do_tcu status_do_edital  ... custo_estimado  \
# 0               Completed           NaN              NaN  ...   2.605232e+09
# 1                     NaN           NaN              NaN  ...   1.817490e-01
# 2             Not started   Not started      Not started  ...   0.000000e+00
# 3               Completed   Not started      Not started  ...   2.552000e+09
# 4               Completed     Completed        Completed  ...   3.719562e+06
#
#   moeda custo_original status_atividade eh_ppp               tipo_projeto  \
# 0   BRL    14000000000           Active   True  Refurbishment/Replacement
# 1   BRL              1           Active   True                        New
# 2   BRL              1              NaN   True  Refurbishment/Replacement
# 3   BRL    14500000000           Active   True                        New
# 4   BRL       21133873              NaN   True  Refurbishment/Replacement
#
#                            arranjo_contratual processo_licitacao  \
# 0                    Concession: Law 8.987/95                NaN
# 1                    Concession: Law 8.987/95                NaN
# 2                    Concession: Law 8.987/95        Competition
# 3  Extension: Law 13.448/17, Art. 4, I and II        Competition
# 4                    Concession: Law 8.987/95        Competition
#
#   outro_arranjo_contratual  outro_processo_licitacao
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
# [5 rows x 32 columns]

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'guid'
# 'nome_projeto'
# 'subsecretaria'
# 'status_atual_do_projeto'
# 'questoes_chaves'
# 'proximas_etapas'
# 'status_dos_estudos'
# 'status_consulta_publica'
# 'status_do_tcu'
# 'status_do_edital'
# 'status_do_leilao'
# 'status_do_contrato'
# 'descricao_do_projeto'
# 'nome_completo'
# 'descricao_curta'
# 'setor'
# 'subsetor'
# 'organizacao'
# 'localizacoes'
# 'latitude'
# 'longitude'
# 'endereco_principal'
# 'custo_estimado'
# 'moeda'
# 'custo_original'
# 'status_atividade'
# 'eh_ppp'
# 'tipo_projeto'
# 'arranjo_contratual'
# 'processo_licitacao'
# 'outro_arranjo_contratual'
# 'outro_processo_licitacao'

# %%
import re
import numpy as np

def extrair_percentual(texto):
    if pd.isna(texto):
        return np.nan
    
    match = re.search(r'(\d{1,3})\s*%', str(texto))
    if match:
        return float(match.group(1))
    
    return np.nan

df["percentual_execucao"] = df["status_atual_do_projeto"].apply(extrair_percentual)

df["percentual_execucao"].describe()
# Out:
# count    27.000000
# mean     62.629630
# std      26.874564
# min       7.000000
# 25%      46.000000
# 50%      71.000000
# 75%      83.500000
# max      99.000000
# Name: percentual_execucao, dtype: float64

# %%
import re
import numpy as np

def extrair_percentual(texto):
    if pd.isna(texto):
        return np.nan
    match = re.search(r'(\d{1,3})\s*%', str(texto))
    if match:
        return float(match.group(1))
    return np.nan

df["percentual_execucao"] = df["status_atual_do_projeto"].apply(extrair_percentual)

# %%
df["custo_estimado"] = pd.to_numeric(df["custo_estimado"], errors="coerce")

# %%
import re
import numpy as np

def extrair_percentual(texto):
    if pd.isna(texto):
        return np.nan
    match = re.search(r'(\d{1,3})\s*%', str(texto))
    if match:
        return float(match.group(1))
    return np.nan

df["percentual_execucao"] = df["status_atual_do_projeto"].apply(extrair_percentual)

# %%
df["custo_estimado"] = pd.to_numeric(df["custo_estimado"], errors="coerce")

# %%
from sklearn.preprocessing import StandardScaler

features_cluster = df[["percentual_execucao", "custo_estimado"]].dropna()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(features_cluster)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

features_cluster["cluster"] = clusters

# %%
df.loc[features_cluster.index, "cluster"] = clusters

# %%
df.groupby("cluster")["percentual_execucao"].mean()
# Out:
# cluster
# 0.0    82.333333
# 1.0    15.000000
# 2.0    45.666667
# Name: percentual_execucao, dtype: float64

# %%
y = df["cluster"]

# %%
df.columns.tolist()
# Out:
# ['guid',
#  'nome_projeto',
#  'subsecretaria',
#  'status_atual_do_projeto',
#  'questoes_chaves',
#  'proximas_etapas',
#  'status_dos_estudos',
#  'status_consulta_publica',
#  'status_do_tcu',
#  'status_do_edital',
#  'status_do_leilao',
#  'status_do_contrato',
#  'descricao_do_projeto',
#  'nome_completo',
#  'descricao_curta',
#  'setor',
#  'subsetor',
#  'organizacao',
#  'localizacoes',
#  'latitude',
#  'longitude',
#  'endereco_principal',
#  'custo_estimado',
#  'moeda',
#  'custo_original',
#  'status_atividade',
#  'eh_ppp',
#  'tipo_projeto',
#  'arranjo_contratual',
#  'processo_licitacao',
#  'outro_arranjo_contratual',
#  'outro_processo_licitacao',
#  'percentual_execucao',
#  'cluster']

# %%
# Garantir que não há espaços invisíveis
df.columns = df.columns.str.strip()

# Trabalhar apenas com linhas que possuem cluster
df_model = df.dropna(subset=["cluster"]).copy()

y = df_model["cluster"]

features = [
    "setor",
    "subsetor",
    "arranjo_contratual",
    "processo_licitacao",
    "custo_estimado"
]

X = df_model[features]

print("Features utilizadas:", features)
print("Shape:", X.shape)
# Out:
# Features utilizadas: ['setor', 'subsetor', 'arranjo_contratual', 'processo_licitacao', 'custo_estimado']
# Shape: (27, 5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

num_cols = ["custo_estimado"]
cat_cols = ["setor", "subsetor", "arranjo_contratual", "processo_licitacao"]

preprocess = ColumnTransformer([
    ("num", StandardScaler(), num_cols),
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols)
])

model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

pipe = Pipeline([
    ("prep", preprocess),
    ("model", model)
])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.83      0.77         6
#          1.0       0.00      0.00      0.00         0
#          2.0       1.00      0.33      0.50         3
#
#     accuracy                           0.67         9
#    macro avg       0.57      0.39      0.42         9
# weighted avg       0.81      0.67      0.68         9
# C:\Users\thiag\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\thiag\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\thiag\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.preprocessing import MinMaxScaler

score_features = df[["percentual_execucao", "custo_estimado"]].copy()

score_features = score_features.fillna(score_features.median())

scaler = MinMaxScaler()

scaled = scaler.fit_transform(score_features)

df["score_maturidade"] = scaled.mean(axis=1)

df["score_maturidade"].describe()
# Out:
# count    209.000000
# mean       0.370555
# std        0.093616
# min        0.010278
# 25%        0.347826
# 50%        0.348527
# 75%        0.362615
# max        0.847826
# Name: score_maturidade, dtype: float64

# %%
def classificar_score(score):
    if score < 0.33:
        return "Baixa"
    elif score < 0.66:
        return "Média"
    else:
        return "Alta"

df["categoria_maturidade"] = df["score_maturidade"].apply(classificar_score)

df["categoria_maturidade"].value_counts()
# Out:
# categoria_maturidade
# Média    191
# Baixa     12
# Alta       6
# Name: count, dtype: int64

# %%
df["atraso_flag"] = (
    (df["percentual_execucao"] < 40) &
    (df["status_do_contrato"].isna())
).astype(int)

df["atraso_flag"].value_counts()
# Out:
# atraso_flag
# 0    205
# 1      4
# Name: count, dtype: int64

# %%
y_atraso = df["atraso_flag"]
X_atraso = df[features]

X_train, X_test, y_train, y_test = train_test_split(
    X_atraso, y_atraso, test_size=0.3, random_state=42
)

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        62
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.94        63
#    macro avg       0.49      0.48      0.48        63
# weighted avg       0.97      0.94      0.95        63

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Matriz de Confusão - Modelo de Maturidade")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x=y)
plt.title("Distribuição das Classes (Cluster)")
plt.xlabel("Cluster")
plt.ylabel("Quantidade")
plt.show()

# %%
import numpy as np

# Extrair nomes das colunas após OneHotEncoder
ohe = pipe.named_steps["prep"].named_transformers_["cat"]
cat_feature_names = ohe.get_feature_names_out(cat_cols)

feature_names = num_cols + list(cat_feature_names)

importances = pipe.named_steps["model"].feature_importances_

feat_imp = (
    pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })
    .sort_values("importance", ascending=False)
    .head(15)
)

plt.figure(figsize=(8,6))
sns.barplot(data=feat_imp, x="importance", y="feature")
plt.title("Top 15 Variáveis Mais Importantes")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["score_maturidade"], bins=20, kde=True)
plt.title("Distribuição do Score Contínuo de Maturidade")
plt.xlabel("Score")
plt.show()

# %%
from sklearn.decomposition import PCA

X_cluster = df_model[["percentual_execucao", "custo_estimado"]].fillna(0)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_cluster)

plt.figure(figsize=(6,5))
sns.scatterplot(
    x=X_pca[:,0],
    y=X_pca[:,1],
    hue=df_model["cluster"],
    palette="Set2"
)
plt.title("Visualização PCA dos Clusters")
plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")
plt.show()

# %%
import pandas as pd
import numpy as np

df_cluster2 = df.copy()

status_cols = [
    'status_dos_estudos',
    'status_consulta_publica',
    'status_do_tcu',
    'status_do_edital',
    'status_do_leilao',
    'status_do_contrato'
]

# Transformar categorias em números (ordinal simples)
for col in status_cols:
    df_cluster2[col] = df_cluster2[col].astype("category").cat.codes

# Criar score médio estrutural
df_cluster2["score_estrutura"] = df_cluster2[status_cols].mean(axis=1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

features_sem_custo = df_cluster2[[
    'percentual_execucao',
    'score_estrutura'
]].fillna(0)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(features_sem_custo)

kmeans2 = KMeans(n_clusters=3, random_state=42)
df_cluster2["cluster_sem_custo"] = kmeans2.fit_predict(X_scaled)

# %%
df_cluster2.groupby("cluster_sem_custo")[[
    "percentual_execucao",
    "score_estrutura"
]].mean()
# Out:
#                    percentual_execucao  score_estrutura
# cluster_sem_custo
# 0                            71.217391         0.717391
# 1                            15.000000        -0.711538
# 2                             8.000000         0.914179

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

for c in df_cluster2["cluster_sem_custo"].unique():
    subset = df_cluster2[df_cluster2["cluster_sem_custo"] == c]
    plt.scatter(
        subset["percentual_execucao"],
        subset["score_estrutura"],
        label=f"Cluster {c}"
    )

plt.xlabel("Percentual de Execução")
plt.ylabel("Score Estrutural")
plt.legend()
plt.title("Clusters SEM Custo Estimado")
plt.show()

# %%
pd.crosstab(
    df["cluster"],
    df_cluster2["cluster_sem_custo"],
    normalize="index"
)
# Out:
# cluster_sem_custo         0    1         2
# cluster
# 0.0                1.000000  0.0  0.000000
# 1.0                0.000000  1.0  0.000000
# 2.0                0.888889  0.0  0.111111

# %%
import pandas as pd

# Caminho do seu arquivo
df = pd.read_excel("projetos_completos_final.xlsx")  # ou .csv

df.head()
# Out:
#                                    guid      nome_projeto subsecretaria  \
# 0  01fb8247-91ec-4631-bf1f-3da9fa6822d6  Projeto 01fb8247          SIEC
# 1  022ea245-c8f4-440a-9a1b-2aa0e2f523fd  Projeto 022ea245          SISU
# 2  03175202-1983-4ce9-9425-f8271bf2e138  Projeto 03175202          SIEC
# 3  03476266-e9a1-4821-8179-8abd15903f7b  Projeto 03476266          SIEC
# 4  07fb13d8-0616-41f8-ab50-99c1c6669fd7  Projeto 07fb13d8          SIEC
#
#                              status_atual_do_projeto  \
# 0  Relatório final aprovado pela ANTT em 29/01/26...
# 1                               Estudos em andamento
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      questoes_chaves  \
# 0                                                NaN
# 1  Delegações do serviço embarcado\nPossibilidade...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      proximas_etapas status_dos_estudos  \
# 0                                                NaN          Completed
# 1  Conclusão dos estudos\nRealizar Consulta/Audiê...                NaN
# 2                                                NaN        In progress
# 3                                                NaN          Completed
# 4                                                NaN          Completed
#
#   status_consulta_publica status_do_tcu status_do_edital  ... custo_estimado  \
# 0               Completed           NaN              NaN  ...   2.605232e+09
# 1                     NaN           NaN              NaN  ...   1.817490e-01
# 2             Not started   Not started      Not started  ...   0.000000e+00
# 3               Completed   Not started      Not started  ...   2.552000e+09
# 4               Completed     Completed        Completed  ...   3.719562e+06
#
#   moeda custo_original status_atividade eh_ppp               tipo_projeto  \
# 0   BRL    14000000000           Active   True  Refurbishment/Replacement
# 1   BRL              1           Active   True                        New
# 2   BRL              1              NaN   True  Refurbishment/Replacement
# 3   BRL    14500000000           Active   True                        New
# 4   BRL       21133873              NaN   True  Refurbishment/Replacement
#
#                            arranjo_contratual processo_licitacao  \
# 0                    Concession: Law 8.987/95                NaN
# 1                    Concession: Law 8.987/95                NaN
# 2                    Concession: Law 8.987/95        Competition
# 3  Extension: Law 13.448/17, Art. 4, I and II        Competition
# 4                    Concession: Law 8.987/95        Competition
#
#   outro_arranjo_contratual  outro_processo_licitacao
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
# [5 rows x 32 columns]

# %%
df.columns.tolist()
# Out:
# ['guid',
#  'nome_projeto',
#  'subsecretaria',
#  'status_atual_do_projeto',
#  'questoes_chaves',
#  'proximas_etapas',
#  'status_dos_estudos',
#  'status_consulta_publica',
#  'status_do_tcu',
#  'status_do_edital',
#  'status_do_leilao',
#  'status_do_contrato',
#  'descricao_do_projeto',
#  'nome_completo',
#  'descricao_curta',
#  'setor',
#  'subsetor',
#  'organizacao',
#  'localizacoes',
#  'latitude',
#  'longitude',
#  'endereco_principal',
#  'custo_estimado',
#  'moeda',
#  'custo_original',
#  'status_atividade',
#  'eh_ppp',
#  'tipo_projeto',
#  'arranjo_contratual',
#  'processo_licitacao',
#  'outro_arranjo_contratual',
#  'outro_processo_licitacao']

# %%
for col in df.columns:
    print(col)
# Out:
# guid
# nome_projeto
# subsecretaria
# status_atual_do_projeto
# questoes_chaves
# proximas_etapas
# status_dos_estudos
# status_consulta_publica
# status_do_tcu
# status_do_edital
# status_do_leilao
# status_do_contrato
# descricao_do_projeto
# nome_completo
# descricao_curta
# setor
# subsetor
# organizacao
# localizacoes
# latitude
# longitude
# endereco_principal
# custo_estimado
# moeda
# custo_original
# status_atividade
# eh_ppp
# tipo_projeto
# arranjo_contratual
# processo_licitacao
# outro_arranjo_contratual
# outro_processo_licitacao

# %%
features_cluster = [
    "percentual execução",
    "custo_estimado"
]

# %%
df.head()
# Out:
#                                    guid      nome_projeto subsecretaria  \
# 0  01fb8247-91ec-4631-bf1f-3da9fa6822d6  Projeto 01fb8247          SIEC
# 1  022ea245-c8f4-440a-9a1b-2aa0e2f523fd  Projeto 022ea245          SISU
# 2  03175202-1983-4ce9-9425-f8271bf2e138  Projeto 03175202          SIEC
# 3  03476266-e9a1-4821-8179-8abd15903f7b  Projeto 03476266          SIEC
# 4  07fb13d8-0616-41f8-ab50-99c1c6669fd7  Projeto 07fb13d8          SIEC
#
#                              status_atual_do_projeto  \
# 0  Relatório final aprovado pela ANTT em 29/01/26...
# 1                               Estudos em andamento
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      questoes_chaves  \
# 0                                                NaN
# 1  Delegações do serviço embarcado\nPossibilidade...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      proximas_etapas status_dos_estudos  \
# 0                                                NaN          Completed
# 1  Conclusão dos estudos\nRealizar Consulta/Audiê...                NaN
# 2                                                NaN        In progress
# 3                                                NaN          Completed
# 4                                                NaN          Completed
#
#   status_consulta_publica status_do_tcu status_do_edital  ... custo_estimado  \
# 0               Completed           NaN              NaN  ...   2.605232e+09
# 1                     NaN           NaN              NaN  ...   1.817490e-01
# 2             Not started   Not started      Not started  ...   0.000000e+00
# 3               Completed   Not started      Not started  ...   2.552000e+09
# 4               Completed     Completed        Completed  ...   3.719562e+06
#
#   moeda custo_original status_atividade eh_ppp               tipo_projeto  \
# 0   BRL    14000000000           Active   True  Refurbishment/Replacement
# 1   BRL              1           Active   True                        New
# 2   BRL              1              NaN   True  Refurbishment/Replacement
# 3   BRL    14500000000           Active   True                        New
# 4   BRL       21133873              NaN   True  Refurbishment/Replacement
#
#                            arranjo_contratual processo_licitacao  \
# 0                    Concession: Law 8.987/95                NaN
# 1                    Concession: Law 8.987/95                NaN
# 2                    Concession: Law 8.987/95        Competition
# 3  Extension: Law 13.448/17, Art. 4, I and II        Competition
# 4                    Concession: Law 8.987/95        Competition
#
#   outro_arranjo_contratual  outro_processo_licitacao
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['guid', 'nome_projeto', 'subsecretaria', 'status_atual_do_projeto',
#        'questoes_chaves', 'proximas_etapas', 'status_dos_estudos',
#        'status_consulta_publica', 'status_do_tcu', 'status_do_edital',
#        'status_do_leilao', 'status_do_contrato', 'descricao_do_projeto',
#        'nome_completo', 'descricao_curta', 'setor', 'subsetor', 'organizacao',
#        'localizacoes', 'latitude', 'longitude', 'endereco_principal',
#        'custo_estimado', 'moeda', 'custo_original', 'status_atividade',
#        'eh_ppp', 'tipo_projeto', 'arranjo_contratual', 'processo_licitacao',
#        'outro_arranjo_contratual', 'outro_processo_licitacao'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# 1️⃣ Garantir que custo é numérico
df["custo_estimado"] = pd.to_numeric(df["custo_estimado"], errors="coerce")

# 2️⃣ Selecionar features disponíveis
features_cluster = [
    "custo_estimado",
    "latitude",
    "longitude"
]

df_cluster = df[features_cluster].dropna()

# 3️⃣ Padronizar
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_cluster)

# 4️⃣ KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
df_cluster["cluster_com_custo"] = kmeans.fit_predict(X_scaled)

# 5️⃣ Salvar no dataframe original
df.loc[df_cluster.index, "cluster_com_custo"] = df_cluster["cluster_com_custo"]

df["cluster_com_custo"].value_counts()
# Out:
# cluster_com_custo
# 0.0    144
# 1.0     51
# 2.0      9
# Name: count, dtype: int64

# %%
# Trocamos df["cluster_sem_custo"] por df_cluster2["cluster_sem_custo"]
pd.crosstab(df["cluster_com_custo"], df_cluster2["cluster_sem_custo"], normalize="index")
# Out:
# cluster_sem_custo         0         1         2
# cluster_com_custo
# 0.0                0.145833  0.236111  0.618056
# 1.0                0.039216  0.294118  0.666667
# 2.0                0.000000  0.222222  0.777778

# %%
df["cluster_sem_custo"] = df_cluster2["cluster_sem_custo"]

from sklearn.metrics import adjusted_rand_score

df_valid = df.dropna(subset=["cluster_sem_custo", "cluster_com_custo"])

ari = adjusted_rand_score(
    df_valid["cluster_sem_custo"],
    df_valid["cluster_com_custo"]
)

print("Adjusted Rand Index:", ari)
# Out:
# Adjusted Rand Index: -0.034758318242561155

# %%
import folium

# Remover projetos sem coordenadas
df_map = df.dropna(subset=["latitude", "longitude"])

# Criar mapa centrado no Brasil
mapa_brasil = folium.Map(
    location=[-14.235, -51.9253], 
    zoom_start=4,
    tiles='OpenStreetMap'
)

# Adicionar marcadores para cada projeto
for idx, row in df_map.iterrows():
    # Usar cluster_com_custo se existir, senão usar um valor padrão
    valor = row.get('cluster_com_custo', 0)
    cor = 'red' if valor == 0 else 'orange' if valor == 1 else 'green'
    
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=8,
        popup=f"<b>{row['nome_projeto']}</b><br>Cluster: {valor}<br>Custo: R${row['custo_estimado']:,.0f}",
        color=cor,
        fill=True,
        fillColor=cor,
        fillOpacity=0.7
    ).add_to(mapa_brasil)

# Salvar mapa como arquivo HTML
mapa_brasil.save("mapa_projetos_ppi.html")
print("Mapa salvo como 'mapa_projetos_ppi.html'")

# Exibir mapa (se o notebook for confiável)
try:
    display(mapa_brasil)
except:
    print("Para visualizar o mapa interativo, abra o arquivo 'mapa_projetos_ppi.html' no navegador")
# Out:
# Mapa salvo como 'mapa_projetos_ppi.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3f47a77b9160f2340060bfdc4fcd64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3f47a77b9160f2340060bfdc4fcd64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec3f47a77b9160f2340060bfdc4fcd64 = L.map(
#                 &quot;map_ec3f47a77b9160f2340060bfdc4fcd64&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bcdbc4f728293c500f89efbb32ce9db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bcdbc4f728293c500f89efbb32ce9db.addTo(map_ec3f47a77b9160f2340060bfdc4fcd64);
#
#
#             var circle_marker_19a8795b67166bf797fe9389fc262756 = L.circleMarker(
#                 [-12.9641527, -38.5058208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ec3f47a77b9160f2340060bfdc4fcd64);
#
#
#         var popup_087b5bab32d06a0aec11abb87cd81227 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e54954022ef44fe2c925db0349372334 = $(`&lt;div id=&quot;html_e54954022ef44fe2c925db0349372334&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 01fb8247&lt;/b&gt;&lt;br&gt;Cluster: 2.0&lt;br&gt;Custo: R$2,605,232,000&lt;/div&gt;`)[0];
#                 popup_087b5bab32d06a0aec11abb87cd81227.setContent(html_e54954022ef44fe2c925db0349372334);
#
#
#
#         circle_marker_19a8795b67166bf797fe9389fc262756.bindPopup(popup_087b5bab32d06a0aec11abb87cd81227)
#         ;
#
#
#
#
#             var circle_marker_299b762fbf4cbbacd4662bed8b44530c = L.circleMarker(
#                 [-3.84028, -32.41083],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ec3f47a77b9160f2340060bfdc4fcd64);
#
#
#         var popup_488e6baa464dfaeb96e202f5f24f8c6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69372532fa11bcec92bf4297591dcf99 = $(`&lt;div id=&quot;html_69372532fa11bcec92bf4297591dcf99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 022ea245&lt;/b&gt;&lt;br&gt;Cluster: 0.0&lt;br&gt;Custo: R$0&lt;/div&gt;`)[0];
#                 popup_488e6baa464dfaeb96e202f5f24f8c6e.setContent(html_69372532fa11bcec92bf4297591dcf99);
#
#
#
#         circle_marker_299b762fbf4cbbacd4662bed8b44530c.bindPopup(popup_488e6baa464dfaeb96e202f5f24f8c6e)
#         ;
#
#
#
#
#             var circle_marker_6bed3297bb7e9be0629f96c3f1abb703 = L.circleMarker(
#                 [-29.738963851058, -53.316114421111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ec3f47a77b9160f2340060bfdc4fcd64);
#
#
#         var popup_a577aaf1fb53db33faf4ce5eacd829c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38787b1e0dd484a238a045b46c6ff038 = $(`&lt;div id=&quot;html_38787b1e0dd484a238a045b46c6ff038&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 03175202&lt;/b&gt;&lt;br&gt;Cluster: 0.0&lt;br&gt;Custo: R$0&lt;/div&gt;`)[0];
#                 popup_a577aaf1fb53db33faf4ce5eacd829c7.setContent(html_38787b1e0dd484a238a045b46c6ff038);

# %%
df["custo_estimado"] = pd.to_numeric(df["custo_estimado"], errors="coerce")

# %%
scaler = MinMaxScaler()

df["custo_norm"] = scaler.fit_transform(
    df[["custo_estimado"]].fillna(0)
)

# %%
cluster_map = {
    0: 0.0,
    1: 0.5,
    2: 1.0
}

df["cluster_risco"] = df["cluster_com_custo"].map(cluster_map)

# %%
def contrato_score(status):
    if pd.isna(status):
        return 0
    status = str(status).lower()
    if "completed" in status:
        return 1.0
    elif "assinado" in status:
        return 0.8
    elif "andamento" in status:
        return 0.6
    elif "não" in status:
        return 0.2
    else:
        return 0.3

df["contrato_score"] = df["status_do_contrato"].apply(contrato_score)

# %%
if "percentual_execucao" in df.columns:
    df["execucao_norm"] = df["percentual_execucao"] / 100
else:
    df["execucao_norm"] = 0.5  # fallback neutro

# %%
df["maturidade"] = (
    0.6 * df["execucao_norm"] +
    0.4 * df["contrato_score"]
)

df["risco"] = (
    0.6 * df["custo_norm"] +
    0.4 * df["cluster_risco"]
)

# %%
df["PRMI"] = (df["maturidade"] * (1 - df["risco"])) * 100

# %%
import matplotlib.pyplot as plt

plt.hist(df["PRMI"].dropna(), bins=20)
plt.title("Distribuição do Project Risk & Maturity Index")
plt.xlabel("PRMI")
plt.ylabel("Quantidade de Projetos")
plt.show()

# %%
df.sort_values("PRMI", ascending=False)[
    ["nome_completo", "PRMI"]
].head(10)
# Out:
#                                          nome_completo       PRMI
# 116  Educação Infantil - Município de Caxias do Sul...  70.000000
# 128                             Aeroporto do Galeão/RJ  70.000000
# 78                 Iluminação Pública - Saquarema (RJ)  69.963850
# 137                           PPP Novo Hospital do GHC  69.767069
# 49                                   Consórcio Mogiana  69.389966
# 159  TRENSURB: Metrô da Região Metropolitana de Por...  68.136551
# 206                                         Api test 1  55.995588
# 48                    Parque Nacional do Caparaó/MG/ES  30.000000
# 20                          Projeto Pontal - Mancha 20  30.000000
# 2    Canal de Acesso Aquaviário do Porto de Rio Gra...  30.000000

# %%
ranking_setor = (
    df.groupby("setor")["PRMI"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

ranking_setor
# Out:
#                    setor       PRMI
# 0  Social Infrastructure  34.027745
# 1         Urban Services  31.756824
# 2          Water & Waste  28.640856
# 3              Transport  27.198909
# 4                  Other  26.875177
# 5                 Energy  24.497116

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.barh(ranking_setor["setor"], ranking_setor["PRMI"])
plt.xlabel("PRMI Médio")
plt.ylabel("Setor")
plt.title("Ranking de Maturidade e Risco por Setor")
plt.gca().invert_yaxis()
plt.show()

# %%
import folium

# Remover projetos sem coordenadas
df_map = df.dropna(subset=["latitude", "longitude", "PRMI"])

# Criar mapa centralizado no Brasil
mapa = folium.Map(location=[-14.2350, -51.9253], zoom_start=4)

for _, row in df_map.iterrows():
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=6,
        popup=f"""
        <b>Projeto:</b> {row['nome_projeto']}<br>
        <b>Setor:</b> {row['setor']}<br>
        <b>PRMI:</b> {round(row['PRMI'],2)}
        """,
        fill=True
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd1a7b1b0b69c1749935fc734a311d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd1a7b1b0b69c1749935fc734a311d8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd1a7b1b0b69c1749935fc734a311d8e = L.map(
#                 &quot;map_fd1a7b1b0b69c1749935fc734a311d8e&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc48ce7c3ccde64fc567ce3963d7be83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc48ce7c3ccde64fc567ce3963d7be83.addTo(map_fd1a7b1b0b69c1749935fc734a311d8e);
#
#
#             var circle_marker_c6fea21ed566291fdce163a6215ac3a8 = L.circleMarker(
#                 [-12.9641527, -38.5058208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd1a7b1b0b69c1749935fc734a311d8e);
#
#
#         var popup_d462ef791599f5fc7619935889311370 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58f2c745d873503ab0b9e0f30c404fc0 = $(`&lt;div id=&quot;html_58f2c745d873503ab0b9e0f30c404fc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Projeto:&lt;/b&gt; Projeto 01fb8247&lt;br&gt;         &lt;b&gt;Setor:&lt;/b&gt; Transport&lt;br&gt;         &lt;b&gt;PRMI:&lt;/b&gt; 8.15         &lt;/div&gt;`)[0];
#                 popup_d462ef791599f5fc7619935889311370.setContent(html_58f2c745d873503ab0b9e0f30c404fc0);
#
#
#
#         circle_marker_c6fea21ed566291fdce163a6215ac3a8.bindPopup(popup_d462ef791599f5fc7619935889311370)
#         ;
#
#
#
#
#             var circle_marker_0df6c5d3090712df62e8930c5e06ea16 = L.circleMarker(
#                 [-3.84028, -32.41083],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd1a7b1b0b69c1749935fc734a311d8e);
#
#
#         var popup_c993886bfc6ef50ad24a7b32f693edcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb1ac79201da11249ab482c14bebf3ad = $(`&lt;div id=&quot;html_bb1ac79201da11249ab482c14bebf3ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Projeto:&lt;/b&gt; Projeto 022ea245&lt;br&gt;         &lt;b&gt;Setor:&lt;/b&gt; Other&lt;br&gt;         &lt;b&gt;PRMI:&lt;/b&gt; 30.0         &lt;/div&gt;`)[0];
#                 popup_c993886bfc6ef50ad24a7b32f693edcc.setContent(html_bb1ac79201da11249ab482c14bebf3ad);
#
#
#
#         circle_marker_0df6c5d3090712df62e8930c5e06ea16.bindPopup(popup_c993886bfc6ef50ad24a7b32f693edcc)
#         ;
#
#
#
#
#             var circle_marker_6af3c9b2c5a388242f0c993cc9ae3111 = L.circleMarker(
#                 [-29.738963851058, -53.316114421111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fd1a7b1b0b69c1749935fc734a311d8e);
#
#
#         var popup_4844fee55860c368acc2c96a5533e5c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec2fd6f767e9e03cdad169e8a70da61a = $(`&lt;div id=&quot;html_ec2fd6f767e9e03cdad169e8a70da61a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Projeto:&lt;/b&gt; Projeto

# %%
def cor_prmi(score):
    if score > 70:
        return "green"
    elif score > 40:
        return "orange"
    else:
        return "red"

mapa = folium.Map(location=[-14.2350, -51.9253], zoom_start=4)

for _, row in df_map.iterrows():
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=7,
        color=cor_prmi(row["PRMI"]),
        fill=True,
        fill_opacity=0.7,
        popup=f"{row['nome_projeto']} | PRMI: {round(row['PRMI'],2)}"
    ).add_to(mapa)

mapa

# %%
import folium

# Remover projetos sem coordenadas
df_map = df.dropna(subset=["latitude", "longitude"])

# Criar mapa centrado no Brasil
mapa_brasil = folium.Map(
    location=[-14.235, -51.9253], 
    zoom_start=4,
    tiles='OpenStreetMap'
)

# Adicionar marcadores para cada projeto
for idx, row in df_map.iterrows():
    # Usar cluster_com_custo se existir, senão usar um valor padrão
    valor = row.get('cluster_com_custo', 0)
    cor = 'red' if valor == 0 else 'orange' if valor == 1 else 'green'
    
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=8,
        popup=f"<b>{row['nome_projeto']}</b><br>Cluster: {valor}<br>Custo: R${row['custo_estimado']:,.0f}",
        color=cor,
        fill=True,
        fillColor=cor,
        fillOpacity=0.7
    ).add_to(mapa_brasil)

# Salvar mapa como arquivo HTML
mapa_brasil.save("mapa_projetos_ppi.html")
print("Mapa salvo como 'mapa_projetos_ppi.html'")

# Exibir mapa (se o notebook for confiável)
try:
    display(mapa_brasil)
except:
    print("Para visualizar o mapa interativo, abra o arquivo 'mapa_projetos_ppi.html' no navegador")
# Out:
# Mapa salvo como 'mapa_projetos_ppi.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5ff7cb252b2c67c10b9910e22732a5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5ff7cb252b2c67c10b9910e22732a5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5ff7cb252b2c67c10b9910e22732a5a = L.map(
#                 &quot;map_e5ff7cb252b2c67c10b9910e22732a5a&quot;,
#                 {
#                     center: [-14.235, -51.9253],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b218088d26720e6aac5132148d71e177 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b218088d26720e6aac5132148d71e177.addTo(map_e5ff7cb252b2c67c10b9910e22732a5a);
#
#
#             var circle_marker_926b265acbd5b97e0fbaac8307d1e8aa = L.circleMarker(
#                 [-12.9641527, -38.5058208],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5ff7cb252b2c67c10b9910e22732a5a);
#
#
#         var popup_db730b1b204689ac5066e3ad4afc361b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_580c76782c3c355f3c8841c94e34f1e8 = $(`&lt;div id=&quot;html_580c76782c3c355f3c8841c94e34f1e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 01fb8247&lt;/b&gt;&lt;br&gt;Cluster: 2.0&lt;br&gt;Custo: R$2,605,232,000&lt;/div&gt;`)[0];
#                 popup_db730b1b204689ac5066e3ad4afc361b.setContent(html_580c76782c3c355f3c8841c94e34f1e8);
#
#
#
#         circle_marker_926b265acbd5b97e0fbaac8307d1e8aa.bindPopup(popup_db730b1b204689ac5066e3ad4afc361b)
#         ;
#
#
#
#
#             var circle_marker_2733796b2843e5da00e3b3b3c135b9c0 = L.circleMarker(
#                 [-3.84028, -32.41083],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5ff7cb252b2c67c10b9910e22732a5a);
#
#
#         var popup_98896ce2acf5b86f63de6d506ce27864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d717202946bc66846c477c9982513d2 = $(`&lt;div id=&quot;html_4d717202946bc66846c477c9982513d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 022ea245&lt;/b&gt;&lt;br&gt;Cluster: 0.0&lt;br&gt;Custo: R$0&lt;/div&gt;`)[0];
#                 popup_98896ce2acf5b86f63de6d506ce27864.setContent(html_4d717202946bc66846c477c9982513d2);
#
#
#
#         circle_marker_2733796b2843e5da00e3b3b3c135b9c0.bindPopup(popup_98896ce2acf5b86f63de6d506ce27864)
#         ;
#
#
#
#
#             var circle_marker_a025a8215991cb75d288abc9294e83a1 = L.circleMarker(
#                 [-29.738963851058, -53.316114421111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5ff7cb252b2c67c10b9910e22732a5a);
#
#
#         var popup_5492b52455cbb52c73f552f20abcc7ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35c722552a6e7f065429036f467c4b5f = $(`&lt;div id=&quot;html_35c722552a6e7f065429036f467c4b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Projeto 03175202&lt;/b&gt;&lt;br&gt;Cluster: 0.0&lt;br&gt;Custo: R$0&lt;/div&gt;`)[0];
#                 popup_5492b52455cbb52c73f552f20abcc7ff.setContent(html_35c722552a6e7f065429036f467c4b5f);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

df_reg = df_cluster2.dropna(subset=['custo_estimado', 'percentual_execucao'])

X = df_reg[['percentual_execucao']]
y = df_reg['custo_estimado']

modelo_linear = LinearRegression()
modelo_linear.fit(X, y)

y_pred = modelo_linear.predict(X)

print("=== RESULTADOS DA REGRESSÃO LINEAR ===")
print(f"R² Score (Precisão): {r2_score(y, y_pred):.4f}")
print(f"Erro Médio Absoluto: R$ {mean_absolute_error(y, y_pred):,.2f}")

# Gráfico da Regressão
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', alpha=0.5, label='Dados Reais (PPI)')
plt.plot(X, y_pred, color='red', linewidth=3, label='Modelo de Previsão')
plt.title('Regressão Linear: O Progresso da Obra explica o Custo?')
plt.xlabel('Percentual de Execução (%)')
plt.ylabel('Custo Estimado (R$)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# === RESULTADOS DA REGRESSÃO LINEAR ===
# R² Score (Precisão): 0.3436
# Erro Médio Absoluto: R$ 205,918,995.10
